# %% [markdown]
# # Data Wrangling, I
# Perform the following operations using Python on dataset(e.g., student.csv)
# 1.Import all the required Python Libraries. And Load the Dataset into pandas data
# frame.
# 2. Data Preprocessing: find the missing values in the data and display statistical
# information.
# 3. Provide variable descriptions. Types of variables etc. Check the dimensions of the data frame
# 4. Data Normalization: Perform min max normalization and plot box plot for any
# column
# 5.Turn categorical variables for PG column into quantitative variables in Python

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\91940\Documents\PR_Exam_DSBDA\PR_EXAM_DATASET\PR_EXAM_DATASET\AcademicPerformance_New.csv")

# %%
df
# Out:
#     Roll No NationalITy    WT  DSBDA    AI    Average Grade   PG
# 0       1.0       India  72.0   72.0  74.0  72.666667     C  Yes
# 1       2.0       Japan  69.0   90.0   NaN  53.000000     B   No
# 2       NaN         NaN   NaN    NaN   NaN        NaN   NaN  NaN
# 3       4.0       China  47.0    NaN  44.0  30.333333     D  Yes
# 4       5.0       India  76.0   78.0   NaN  51.333333     C   No
# ..      ...         ...   ...    ...   ...        ...   ...  ...
# 94     95.0         USA  79.0    NaN   NaN  26.333333     A   No
# 95     96.0       Japan  78.0   81.0  82.0  80.333333     A   No
# 96     97.0         USA  65.0   66.0  62.0  64.333333     B   No
# 97     98.0      Rassia  63.0   72.0  70.0  68.333333     B  Yes
# 98     99.0       India  58.0   67.0   NaN  41.666667     B   No
#
# [99 rows x 8 columns]

# %%
#findin inconsistence and missing values
df.isnull().sum()
# Out:
# Roll No         1
# NationalITy     1
# WT              8
# DSBDA           4
# AI             10
# Average         1
# Grade           1
# PG              1
# dtype: int64

# %%
#statistical information
df.describe()
# Out:
#          Roll No         WT      DSBDA         AI    Average
# count  98.000000  91.000000  95.000000  89.000000  98.000000
# mean   50.479592  61.164835  64.652632  62.235955  58.663265
# std    28.469274  14.995009  14.893072  16.216590  16.518482
# min     1.000000  18.000000  26.000000  20.000000  26.000000
# 25%    26.250000  51.000000  54.500000  52.000000  45.250000
# 50%    50.500000  63.000000  66.000000  63.000000  59.333333
# 75%    74.750000  71.000000  74.000000  74.000000  71.916667
# max    99.000000  97.000000  95.000000  92.000000  91.666667

# %%
df.dtypes
# Out:
# Roll No        float64
# NationalITy     object
# WT             float64
# DSBDA          float64
# AI             float64
# Average        float64
# Grade           object
# PG              object
# dtype: object

# %%
df.shape
# Out:
# (99, 8)

# %%
df.ndim
# Out:
# 2

# %%
min_val = df['Average'].min()
max_val = df['Average'].max()
df['Average'+'_min_max'] = (df['Average'] - min_val) / (max_val - min_val)

df['Average'+'_min_max']
# Out:
# 0     0.710660
# 1     0.411168
# 2          NaN
# 3     0.065990
# 4     0.385787
#         ...
# 94    0.005076
# 95    0.827411
# 96    0.583756
# 97    0.644670
# 98    0.238579
# Name: Average_min_max, Length: 99, dtype: float64

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df['PG'].isnull().sum()
# Out:
# 1

# %%
df['PG']=df['PG'].fillna(df['PG'].mode)

# %%
df['PG'].isnull().sum()
# Out:
# 0

# %%
pg=['PG']
quanPG=pd.get_dummies(df,columns=pg,drop_first=True)
quanPG
# Out:
#     Roll No NationalITy    WT  DSBDA    AI    Average Grade  Average_min_max  \
# 0       1.0       India  72.0   72.0  74.0  72.666667     C         0.710660
# 1       2.0       Japan  69.0   90.0   NaN  53.000000     B         0.411168
# 2       NaN         NaN   NaN    NaN   NaN        NaN   NaN              NaN
# 3       4.0       China  47.0    NaN  44.0  30.333333     D         0.065990
# 4       5.0       India  76.0   78.0   NaN  51.333333     C         0.385787
# ..      ...         ...   ...    ...   ...        ...   ...              ...
# 94     95.0         USA  79.0    NaN   NaN  26.333333     A         0.005076
# 95     96.0       Japan  78.0   81.0  82.0  80.333333     A         0.827411
# 96     97.0         USA  65.0   66.0  62.0  64.333333     B         0.583756
# 97     98.0      Rassia  63.0   72.0  70.0  68.333333     B         0.644670
# 98     99.0       India  58.0   67.0   NaN  41.666667     B         0.238579
#
#     PG_No  PG_Yes
# 0   False    True
# ...

# %%
df
# Out:
#     Roll No NationalITy    WT  DSBDA    AI    Average Grade  \
# 0       1.0       India  72.0   72.0  74.0  72.666667     C
# 1       2.0       Japan  69.0   90.0   NaN  53.000000     B
# 2       NaN         NaN   NaN    NaN   NaN        NaN   NaN
# 3       4.0       China  47.0    NaN  44.0  30.333333     D
# 4       5.0       India  76.0   78.0   NaN  51.333333     C
# ..      ...         ...   ...    ...   ...        ...   ...
# 94     95.0         USA  79.0    NaN   NaN  26.333333     A
# 95     96.0       Japan  78.0   81.0  82.0  80.333333     A
# 96     97.0         USA  65.0   66.0  62.0  64.333333     B
# 97     98.0      Rassia  63.0   72.0  70.0  68.333333     B
# 98     99.0       India  58.0   67.0   NaN  41.666667     B
#
#                                                    PG  Average_min_max
# 0                                                 Yes         0.710660
# 1                                                  No         0.411168
# ...
